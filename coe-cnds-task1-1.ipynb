# %%
# !pip install torch torchvision torchaudio cudatoolkit
# !pip install paddlepaddle-gpu
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement cudatoolkit (from versions: none)
# ERROR: No matching distribution found for cudatoolkit
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.9/758.9 MB 2.2 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt_einsum 3.4.0
#     Uninstalling opt_einsum-3.4.0:
#       Successfully uninstalled opt_einsum-3.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# ...

# %%
# !pip install paddlepaddle paddleocr pytesseract pdf2image \
            opencv-python transformers torch langid polyglot \
            pdfminer.six

# Install Tesseract language data
# !apt-get install tesseract-ocr
# !apt-get install tesseract-ocr-chi  # Chinese
# !apt-get install tesseract-ocr-mar  # Marathi
# !apt-get install tesseract-ocr-urd  # Urdu
# !apt-get install tesseract-ocr-ben  # Bengali
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.3/126.3 kB 3.0 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 85.2 kB/s eta 0:00:00ta 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 MB 13.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.7/544.7 kB 26.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.9/161.9 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 89.4 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 77.0 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 96.8 MB/s eta 0:00:00:00:010:01
# ...

# %%
# !apt-get update && apt-get install -y poppler-utils tesseract-ocr
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [66.7 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,309 kB]
# Get:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# ...

# %%
# !pip install pyicu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.9/263.9 kB 5.7 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for pyicu: filename=PyICU-2.14-cp310-cp310-linux_x86_64.whl size=1809885 sha256=a6dadb8eb62257703e93b3a97cdc7596a46b686bb00f1a33397e7bfe11ddb06a
#   Stored in directory: /root/.cache/pip/wheels/78/6e/76/17c73021179c06c29d9b108896b9248da0de4f2af93f63d405
# Successfully built pyicu
# ...

# %%
# !pip install pycld2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 MB 34.1 MB/s eta 0:00:00:00:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pycld2: filename=pycld2-0.41-cp310-cp310-linux_x86_64.whl size=9904073 sha256=76270d40c33a9a1c8dce37aa2d3d85a3e31eae2e0d9c52c25efd9b46b2d1a3b1
#   Stored in directory: /root/.cache/pip/wheels/be/81/31/240c89c845e008a93d98542325270007de595bfd356eb0b06c
# Successfully built pycld2
# ...

# %%
# !pip install PyPDF2
# !pip install pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 58.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 71.6 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: pdfminer.six
#     Found existing installation: pdfminer.six 20240706
#     Uninstalling pdfminer.six-20240706:
#       Successfully uninstalled pdfminer.six-20240706
# ...

# %%
from pdf2image import convert_from_path
import pytesseract
from PIL import Image
import cv2
import numpy as np
import gc  

def preprocess_image(image):
    """Preprocess scanned images to improve OCR accuracy."""
    gray = cv2.cvtColor(np.array(image), cv2.COLOR_BGR2GRAY)
    
    _, binary = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
    
    kernel = np.ones((1, 1), np.uint8)
    processed_image = cv2.dilate(binary, kernel, iterations=1)
    
    return Image.fromarray(processed_image)

def extract_text_from_pdf(pdf_path, batch_size=50):
    """Extract text from scanned PDFs using OCR in batches for memory optimization."""
    try:
        text = ''
        
        images = convert_from_path(pdf_path, dpi=300) 
        
        for i in range(0, len(images), batch_size):
            batch_images = images[i:i + batch_size]  
            
            for image in batch_images:
                processed_image = preprocess_image(image)
                text += pytesseract.image_to_string(processed_image, 
                                                    lang='mar+eng+ben+chi+urd',  
                                                    config="--psm 6 --oem 1")  
            
            del batch_images
            gc.collect()
            return text
    except Exception as e:
        print(f"Error extracting text: {e}")
        return None


pdf_path = "/kaggle/input/pdddffs/allpdfs/Notification-for-Other-Nationals.pdf"
extracted_text = extract_text_from_pdf(pdf_path, batch_size=50)
print(extracted_text)
# Out:
# DAGeneralt 2024\Circutar. 32
# yOu
# 2५८०८००५७७ OK 2
# ১৮৫ क ৬টি ap ٠ 72 7 >
# ৮৮০০০ ‏۸ے ۱ سردس رای جنر لابو‎
# (re) ০
# ‏نیڈ‎
# ‏و‎ | 1৮৮, ۱ ۱
# ‏ور :06 من 2024ء‎ 2023/0106)12-০15/2//2
# চি
# 2০ Tha AP ‏جنا‎ A
# ७० we rE ‏جف‎ Je 4 ‏خر‎ টে
# CoP Hz MSAK SM he 2
# ‏لیک رٹری صاحبانعکومت, ۲ آ زارکومتر پاست جموں فی‎ 3
# ১74 ০৫1০৫৯//5৮7৮4605984৮ 4
# ۱ Coste 7 Zz ১7৮2০ 2 5
# 2 1৮/৮/১৮১৬৮%৮৪৪৯৯৬৬০৮০৮৮৮৮%৭৭৬৪ ‏اض تو‎ we टं 4 5 ‏عو‎
# ‎(reli, GLb WPI Mey Zr be elas eB ‏ان:‎
# ‎1 ट्र
# ‏ملا میم‎
# ‏یر‎ পা ‏جو کے‎ ٠ ৯ ৭ ‏گنو‎ ৬ ۰ a ‏عو‎
# ‎farts 74৮1-47/-৮597584 WIT Le ‏معاملیمنوان الصدر یر رخدیمت‎
# CPL ‏سرانجام دے سے ہیں ء‎ tebels ‏ری خدفتارا‎ BRL Ede ‏حب بحالیا تک‎ lo ‏برعداات العالیہ نے ڈ پاش‎
# ‏میس لاگی چاککرر پورٹ ارسا لکمہ نے اعم صادرفر ایا ے۔‎ ৮4৯ ee lee ‏اجراء ہونےے وا نے پاشترہ‎
# ee SiS SUI 09-02-2024 L ‏عرالت العالیہ‎
# "Moreover, the Deputy Commissioner Rehabilitation is further directed to probe into the
# ...

# %%
from langdetect import detect_langs

def detect_language_unicode(text):
    """Detects language probabilities based on Unicode character distribution."""
    
    lang_counts = {
        'bengali': sum(1 for char in text if '\u0980' <= char <= '\u09FF'),
        'chinese': sum(1 for char in text if '\u4E00' <= char <= '\u9FFF'),
        'urdu': sum(1 for char in text if '\u0600' <= char <= '\u06FF'),
        'marathi': sum(1 for char in text if '\u0900' <= char <= '\u097F'),
        'english': sum(1 for char in text if '\u0041' <= char <= '\u007A'),
    }
    
    total_chars = sum(lang_counts.values())  
    lang_probs = {lang: count / total_chars for lang, count in lang_counts.items() if total_chars > 0}

   
    sorted_langs = sorted(lang_probs.items(), key=lambda x: x[1], reverse=True)
    
   
    top_langs = [lang for lang, _ in sorted_langs[:2]] 

    def filter_text_by_lang(text, lang):
        return "".join(char for char in text if (
            (lang == 'bengali' and '\u0980' <= char <= '\u09FF') or
            (lang == 'chinese' and '\u4E00' <= char <= '\u9FFF') or
            (lang == 'urdu' and '\u0600' <= char <= '\u06FF') or
            (lang == 'marathi' and '\u0900' <= char <= '\u097F') or
            (lang == 'english' and '\u0041' <= char <= '\u007A')
        ))

    filtered_texts = {lang: filter_text_by_lang(text, lang) for lang in top_langs}

    return top_langs, lang_probs, filtered_texts  

top_languages, probabilities, filtered_texts = detect_language_unicode(extracted_text)

print("\n Detected Language Probabilities:")
for lang, prob in probabilities.items():
    print(f"  {lang.capitalize()}: {prob:.2%}")

print("\n Filtered Texts:")
for i, lang in enumerate(top_languages):
    print(f"\n {i+1}. {lang.capitalize()} Text:")
    print(filtered_texts[lang] if filtered_texts[lang] else "[No significant text detected]")
# Out:
#  Detected Language Probabilities:
#   Bengali: 8.70%
#   Chinese: 0.00%
#   Urdu: 28.55%
#   Marathi: 4.35%
#   English: 58.40%
#
#  Filtered Texts:
#
#  1. English Text:
# DAGeneralt\...
#
#  2. Urdu Text:
# ٠۸ے۱سردسرایجنرلابونیڈو۱۱ورمنءجناجفخرلیکرٹریصاحبانعکومت۲آزارکومترپاستجموںفی۱اضتوعوانملامیمیرجوکے٠گنو۰عومعاملیمنوانالصدریررخدیمتسرانجامدےسےہیںءریخدفتاراحببحالیاتکبرعدااتالعالیہنےڈپاشمیسلاگیچاککررپورٹارسالکمہنےاعمصادرفرایاے۔اجراءہونےےوانےپاشترہعرالتالعالیہیشیےچانکاامامخرمایاجاۓاکبمنشاءفیصلمحززعدالتالحالتحقیقاتمصدکومیںواللامیاالاخدمت۔صاحببراۓجناپصدرڑاکوریربینابےرؤینآسےمررترلہ

# %%
# !pip install langdetect
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 2.7 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=182d37b352add1140fc336f045aafa10a7c3a5bc9f21847fc3bae603a3b170b1
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...
